# %%
import pycaret
from pycaret.regression import *

# %%
train = pd.read_csv("Hackathon_2022/resources/train_preprocessed_HK_IZ.csv")

# %%
train.head(10)
# Out:
#    floor  total_floor  gym  lift  property_age  property_size  swimming_pool  \
# 0      3          4.0    1     1             2      -0.187832              1
# 1      4         11.0    1     1             1       0.430529              1
# 2      0          4.0    1     1             0       0.377250              0
# 3      3          4.0    0     0             1       0.538702              0
# 4      1          2.0    0     0             4      -0.833639              0
# 5      2          2.0    1     0             8       0.377250              1
# 6      1          3.0    1     1             5      -0.591461              1
# 7      0          5.0    1     1            18      -0.268558              1
# 8      0          2.0    1     0            15       1.668866              1
# 9      1          2.0    1     0             8      -0.591461              0
#
#        rent   deposit  type  furnishing  lease_type  locality  parking  \
# ...

# %%
test = pd.read_csv("Hackathon_2022/resources/test_preprocessed_HK_IZ.csv")

# %%
print(train.select_dtypes(exclude=np.number).columns)
# Out:
# Index(['property_id'], dtype='object')

# %%
exp_name = setup(data = train, target = 'count', categorical_features=['property_id'])
# Out:
# <style type="text/css">
# #T_2ec74_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2ec74_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ec74_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2ec74_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_2ec74_row0_col1" class="data row0 col1" >4999</td>
#     </tr>
#     <tr>
#       <th id="T_2ec74_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2ec74_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_2ec74_row1_col1" class="data row1 col1" >count</td>
#     </tr>
#     <tr>
#       <th id="T_2ec74_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2ec74_row2_col0" class="data row2 col0" >Original Data</td>
# ...

# %%
best_model = compare_models(exclude=['gbr', 'ridge', 'en', 'huber', 'llar', 'knn', 'dt', 'ada', 'par'])
# Out:
# IntProgress(value=0, description='Processing: ', max=54)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          00:13:49
# Status     . . . . . . . . . . . . . . . . . .  Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .    Bayesian Ridge
# <style type="text/css">
# #T_7eb5e_ th {
#   text-align: left;
# }
# #T_7eb5e_row0_col0, #T_7eb5e_row0_col1, #T_7eb5e_row0_col2, #T_7eb5e_row0_col3, #T_7eb5e_row0_col4, #T_7eb5e_row0_col5, #T_7eb5e_row0_col6, #T_7eb5e_row0_col7, #T_7eb5e_row1_col0, #T_7eb5e_row1_col1, #T_7eb5e_row1_col2, #T_7eb5e_row1_col3, #T_7eb5e_row1_col4, #T_7eb5e_row1_col5, #T_7eb5e_row1_col6, #T_7eb5e_row1_col7, #T_7eb5e_row2_col0, #T_7eb5e_row2_col1, #T_7eb5e_row2_col2, #T_7eb5e_row2_col3, #T_7eb5e_row2_col4, #T_7eb5e_row2_col5, #T_7eb5e_row2_col6, #T_7eb5e_row2_col7, #T_7eb5e_row3_col0, #T_7eb5e_row3_col1, #T_7eb5e_row3_col2, #T_7eb5e_row3_col3, #T_7eb5e_row3_col4, #T_7eb5e_row3_col5, #T_7eb5e_row3_col6, #T_7eb5e_row3_col7 {
#   text-align: left;
# ...
